# %%
import json

# %%
with open('pos_0.png.json') as f1:             
    data1 = json.load(f1)
    result1 = json.dumps(data1 , indent = 2)
    
with open('pos_10010.png.json') as f2:                       
    data2 = json.load(f2)
    result2 = json.dumps(data2 , indent = 2)
    
with open('pos_10492.png.json') as f3:                    
    data3 = json.load(f3)
    result3 = json.dumps(data3 , indent = 2)
    

result = result1 + result2 + result3

print(result)
result.replace ("vehicle", "car") 
result.replace("license plate" , "number")
print(result)
# Out:
# {
#   "description": "",
#   "tags": [],
#   "size": {
#     "height": 720,
#     "width": 1280
#   },
#   "objects": [
#     {
#       "id": 28602834,
#       "classId": 17389,
#       "description": "",
#       "geometryType": "rectangle",
#       "labelerLogin": "muyeed",
#       "createdAt": "2021-11-24T04:04:09.702Z",
#       "updatedAt": "2021-11-24T04:04:09.702Z",
#       "tags": [
#         {
#           "id": 29485103,
#           "tagId": 32292,
#           "name": "Type",
#           "value": "SUV",
#           "labelerLogin": "muyeed",
#           "createdAt": "2021-11-24T04:04:09.702Z",
#           "updatedAt": "2021-11-24T04:04:09.702Z"
#         },
#         {
#           "id": 29485102,
#           "tagId": 32295,
#           "name": "Pose",
#           "value": "Rear",
#           "labelerLogin": "muyeed",
#           "createdAt": "2021-11-24T04:04:09.702Z",
#           "updatedAt": "2021-11-24T04:04:09.702Z"
#         },
#         {
#           "id": 29485101,
# ...
